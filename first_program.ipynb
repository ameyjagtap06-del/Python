# %%
_num = 20
print(_num + 5)
# Out:
# 25

# %%
import keyword

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
3name = 'Amey'
# Out:
#   Cell In[9], line 1
#     3name = 'Amey'
#     ^
# SyntaxError: invalid decimal literal

# %%
name3 = "Amey"

# %%
type(name3)
# Out:
# str

# %%
list_1 = ["Amey", 1, 20.5]
print(1 in list_1)
# Out:
# True

# %%
type(list_1)
# Out:
# list

# %%
 python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 python
#
# NameError: name 'python' is not defined

# %%
a = 85
b = 14
c = a + b
c
# Out:
# 99

# %%
a=input("Enter the any value")
a
# Out:
# Enter the any value 5
# '5'

# %%
type(a)
# Out:
# str

# %%
b=int(a)

# %%
type(b)
# Out:
# int

# %%
c = False

# %%
type(c)
# Out:
# bool

# %%
int(c)
# Out:
# 0

# %%
a = int(input("Enter the any value"))
# Out:
# Enter the any value 8

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b = int(input("Enter the value of b"))
b
# Out:
# Enter the value of b 5

# %%
c = a+b
c
# Out:
# 13

# %%
j = True

# %%
type(j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 type(j)
#
# NameError: name 'j' is not defined

# %%
num_1 = int(input("Enter the value"))
num_2 = int(input("Enter the another value"))
c = num_1 + num_2
print(f"Addition of {num_1} and {num_2} is{c}")
# Out:
# Enter the value 5
# Enter the another value 8
# Addition of 5 and 8 is13

# %%
print("Hello", end = " ")
print("Amey")
# Out:
# Hello Amey

# %%
num_1 = int(input("Enter the value"))
num_2 = int(input("Enter the another value"))
c = num_1 * num_2
print(f"Multiplication of {num_1} and {num_2} is {c}")
# Out:
# Enter the value 8
# Enter the another value 4
# Multiplication of 8 and 4 is 32

# %%
num_1 = int(input("Enter the value"))
num_2 = int(input("Enter the another value"))
c = num_1 - num_2
print(f"Subtraction of {num_1} and {num_2} is{c}")
# Out:
# Enter the value 52
# Enter the another value 10
# Subtraction of 52 and 10 is42

# %%
num_1 = int(input("Enter the value"))
num_2 = int(input("Enter the another value"))
c = num_1 / num_2
print(f"Division of {num_1} and {num_2} is{c}")
# Out:
# Enter the value 10
# Enter the another value 5
# Division of 10 and 5 is2.0

# %%
num_1 = int(input("Enter the value"))
num_2 = int(input("Enter the another value"))
c = num_1 // num_2
print(f"Integer Division of {num_1} and {num_2} is {c}")
# Out:
# Enter the value 10
# Enter the another value 5
# Integer Division of 10 and 5 is 2

# %%
num_1 = int(input("Enter the value"))
num_2 = int(input("Enter the another value"))
c = num_1 % num_2
print(f"Modulas of {num_1} and {num_2} is {c}")
# Out:
# Enter the value 10
# Enter the another value 5
# Modulas of 10 and 5 is 0

# %%
# write a program to calculate area of circle

# %%
r = int(input("Enter the radius of circle"))
area = 3.14*r*r
print("Area of circle", area)
# Out:
# Enter the radius of circle 12
# Area of circle 452.15999999999997

# %%
# Calculate area of triangle

# %%
base = int(input("Enter the base"))
height = int(input("Enter the height"))
area_of_triangle = 0.5*base*height
print("Area of Traingle", area_of_triangle)
# Out:
# Enter the base 5
# Enter the height 7
# Area of Traingle 17.5

# %%
# Calculate square root of user even no

# %%
Even = int(input("Enter the Even no"))
root = Even ** 0.5
print("The Square root of even no is ", root)
# Out:
# Enter the Even no 25
# The Square root of even no is  5.0

# %%
# Conditional Statements IF

# %%
n1 = int(input("Enter The First number"))
n2 = int(input("Enter The Second number"))
if (n1 > n2):
    print(f"{n1} is Greater than {n2}")
print("Condition Is True")
# Out:
# Enter The First number 25
# Enter The Second number 10
# 25 is Greater than 10
# Condition Is True

# %%
# Conditional Statements IF Else

# %%
n1 = int(input("Enter The First number"))
n2 = int(input("Enter The Second number"))
if (n1 > n2):
    print(f"{n1} is Greter than {n2}")
elif(n2 > n1):
    print(f"{n2} is Greater than {n1}")
print("Elif Condition Is True")
# Out:
# Enter The First number 25
# Enter The Second number 78
# 78 is Greater than 25
# Elif Condition Is True

# %%
# Conditional Statements IF Else

# %%
n1 = int(input("Enter The First number"))
n2 = int(input("Enter The Second number"))
if (n1 > n2):
    print(f"{n1} is Greter than {n2}")
elif(n2 > n1):
    print(f"{n2} is Greater than {n1}")
else:
    print(f"{n1} and {n2} are both Equal")
print("Else Condition Is True")
# Out:
# Enter The First number 25
# Enter The Second number 25
# 25 and 25 are both Equal
# Else Condition Is True

# %%
# Write a program to check user given no is positive or negative

# %%
Number = int(input("Enter the number"))
if (Number >= 0):
    print(f" {Number} is positive")
else:
    print(f"{Number} is negative")
# Out:
# Enter the number -3
# -3 is negative

# %%
#write program to check even or odd number

# %%
number = int(input("Enter the number"))
if (number % 2==0):
    print(f"{number} is Even")
else:
    print(f"{number} is odd")
# Out:
# Enter the number 5
# 5 is odd

# %%
# Write a  program take n. from 0 to 9 from user and print it in words and Roman
